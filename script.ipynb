-- %% [markdown]
-- # [dbo].[CARS]

-- %%
USE [BookingAppApiDb]
GO

-- %%
/****** Object:  Table [dbo].[CARS]    Script Date: 11/12/2023 6:24:52 μμ ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CARS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[USER_ID] [int] NULL,
	[IS_VISIBLE] [bit] NULL,
	[BRAND] [nvarchar](50) NULL,
	[MODEL] [nvarchar](50) NULL,
	[YEAR] [nvarchar](50) NULL,
	[SEAT] [nvarchar](50) NULL,
	[CC] [nvarchar](50) NULL,
	[TRANSMISSION] [nvarchar](50) NULL,
	[PRICE] [float] NULL,
	[PHOTO_URL] [nvarchar](max) NULL,
	[PHOTO_ID] [nvarchar](50) NULL,
 CONSTRAINT [PK__CARS__3214EC275B16CD1E] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[RESERVATIONS]

-- %%
/****** Object:  Table [dbo].[RESERVATIONS]    Script Date: 11/12/2023 6:24:53 μμ ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[RESERVATIONS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[USER_ID] [int] NULL,
	[CAR_ID] [int] NULL,
	[STARTING_DATE] [datetime] NULL,
	[ENDING_DATE] [datetime] NULL,
 CONSTRAINT [PK__RESERVAT__3214EC27486CE380] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[USERS]

-- %%
/****** Object:  Table [dbo].[USERS]    Script Date: 11/12/2023 6:24:53 μμ ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[USERS](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[USERNAME] [nvarchar](50) NULL,
	[PASSWORD] [nvarchar](max) NULL,
	[FIRSTNAME] [nvarchar](50) NULL,
	[LASTNAME] [nvarchar](50) NULL,
	[EMAIL] [nvarchar](50) NULL,
	[PHONE] [nvarchar](50) NULL,
	[IS_OWNER] [bit] NULL,
 CONSTRAINT [PK__USERS__3214EC27450F6C37] PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_CARS_TO_USER]

-- %%
ALTER TABLE [dbo].[CARS]  WITH CHECK ADD  CONSTRAINT [FK_CARS_TO_USER] FOREIGN KEY([USER_ID])
REFERENCES [dbo].[USERS] ([ID])
GO
ALTER TABLE [dbo].[CARS] CHECK CONSTRAINT [FK_CARS_TO_USER]
GO

-- %% [markdown]
-- # [FK_RESERVATIONS_TO_CARS]

-- %%
ALTER TABLE [dbo].[RESERVATIONS]  WITH CHECK ADD  CONSTRAINT [FK_RESERVATIONS_TO_CARS] FOREIGN KEY([CAR_ID])
REFERENCES [dbo].[CARS] ([ID])
GO
ALTER TABLE [dbo].[RESERVATIONS] CHECK CONSTRAINT [FK_RESERVATIONS_TO_CARS]
GO

-- %% [markdown]
-- # [FK_RESERVATIONS_TO_USERS]

-- %%
ALTER TABLE [dbo].[RESERVATIONS]  WITH CHECK ADD  CONSTRAINT [FK_RESERVATIONS_TO_USERS] FOREIGN KEY([USER_ID])
REFERENCES [dbo].[USERS] ([ID])
GO
ALTER TABLE [dbo].[RESERVATIONS] CHECK CONSTRAINT [FK_RESERVATIONS_TO_USERS]
GO
